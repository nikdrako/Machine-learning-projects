# %% [markdown]
# <a href="https://colab.research.google.com/github/nikdrako/Machine-learning-projects/blob/main/Homework_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download uk_core_news_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.2/231.2 MB 28.7 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('uk_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("uk_core_news_lg")
import requests
from bs4 import BeautifulSoup


url = "https://uk.wikipedia.org/wiki/%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%81%D1%8C%D0%BA%D0%B0_%D0%94%D0%B5%D1%80%D0%B6%D0%B0%D0%B2%D0%B0" #Українська держава 1918
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

paragraphs = soup.find_all("p")
article_text = " ".join([p.get_text() for p in paragraphs])

print(article_text[:1000])
# Out:
# На цій сторінці показано неперевірені зміни  Украї́нська Держа́ва (Другий Гетьманат) — держава, що охоплювала територію Північної, Центральної, Східної (за винятком незначної частини Донецької та Луганської областей) та Південної України (за винятком Південної Бессарабії і Криму), а також суміжних українських етнічних земель, що охоплювали більшу частину сучасних Берестейської та Гомельської областей Білорусі, територію Придністров'я та окремі райони на півночі Молдови, більшу частину Брянської (Стародубщина), Білгородської та Воронезької (де-факто лише захід та південь) та південну частину Курської областей Росії, а також Холмщину та частину Підляшшя у межах сучасної Польщі (що де-факто контролювалися австрійськими військами), зі столицею у Києві з 29 квітня до 14 грудня 1918 року. Постала на місці Української Народної Республіки внаслідок гетьманського перевороту. Очолювалась гетьманом Павлом Скоропадським.
# ...

# %%
doc = nlp(article_text)
print(doc.ents)
for ent in doc.ents:
  print(ent.text, "-", ent.label_)
# Out:
# (Украї́нська Держа́ва, Другий Гетьманат, Північної, Центральної, Східної, Донецької та Луганської областей, Південної України, Південної Бессарабії, Криму, Берестейської та Гомельської областей Білорусі, Придністров'я, Молдови, Брянської, Стародубщина, Білгородської, Воронезької, Курської областей Росії, Холмщину, Підляшшя, Польщі, Києві, Української Народної Республіки, Павлом Скоропадським, Скоропадський, Центральну Раду, Російської імперії, Кубанню, Кримом, Доном, Німецької імперії, Австро, Угорщину, Української держави, Центральних держав, Берестейським мирним договором, України, Центральної ради, Центральної Ради, УНС, Антанти, Росією, Павла Скоропадського, П. Болбочана, Симона Петлюри, Гетьманату, Фрідріха Блахау, Україну, Німеччині[4, України, Одеси, Катеринославської губернії, УНР, Директорією, Німеччини, Австро, Угорщини, Центральна Рада, Української Народної Республіки, Києва, Україні, Брест, України, Українська Народна Громада, Україні, Павла Скоропадського, Центральної Ра
# ...

# %%
from spacy import displacy
displacy.render(doc[:],style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">На цій сторінці показано неперевірені зміни
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Украї́нська Держа́ва
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Другий Гетьманат
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) — держава, що охоплювала територію
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Північної, Центральної, Східної
# ...
